# %% [markdown]
# ## Globals

# %%
import pandas as pd
import numpy as np
import os

datasets=["edu","inc", "urb"]
root=os.getcwd().removesuffix("sandbox")

# %% [markdown]
# ## Loading clean datasets

# %%
clean_folder=root+"data/datasets_clean/"
cleans={}

# Loading clean datasets to memory
for dataset in ["education","income","urbanisation"]:
    ds_path=clean_folder+"freq_"+str(dataset)+"_cleaned.csv"
    print(ds_path)
    cleans[dataset[:3]]=pd.read_csv(ds_path,sep=";",index_col=0)

cleans["edu"]
# Out:
# /home/meru/University/5thYear/IDS/datascience-miniproject/data/datasets_clean/freq_education_cleaned.csv
# /home/meru/University/5thYear/IDS/datascience-miniproject/data/datasets_clean/freq_income_cleaned.csv
# /home/meru/University/5thYear/IDS/datascience-miniproject/data/datasets_clean/freq_urbanisation_cleaned.csv
#                       age             geo      sex  \
# 0        75 years or over         Austria  Females
# 1        75 years or over         Austria  Females
# 2        75 years or over         Austria  Females
# 6        75 years or over         Austria    Males
# 7        75 years or over         Austria    Males
# ...                   ...             ...      ...
# 2389  From 65 to 74 years  United Kingdom  Females
# 2390  From 65 to 74 years  United Kingdom  Females
# 2391  From 65 to 74 years  United Kingdom    Males
# 2392  From 65 to 74 years  United Kingdom    Males
# 2393  From 65 to 74 years  United Kingdom    Males
#
#                                                 isced11  Every day  \
# 0     Less than primary, primary and lower secondary...        5.0
# 1                       Tertiary education (levels 5-8)        7.5
# 2     Upper secondary and post-secondary non-tertiar...        8.1
# 6     Less than primary, primary and lower secondary...       29.7
# 7                       Tertiary education (levels 5-8)       26.2
# ...                                                 ...        ...
# 2389                    Tertiary education (levels 5-8)       13.4
# 2390  Upper secondary and post-secondary non-tertiar...        9.3
# 2391  Less than primary, primary and lower secondary...       12.8
# 2392                    Tertiary education (levels 5-8)       23.6
# 2393  Upper secondary and post-secondary non-tertiar...       18.1
#
#       Every month  Every week  Less than once a month  \
# 0            22.8        12.3                    16.8
# 1            35.1        16.8                     7.4
# 2            23.3        23.4                    19.9
# 6            17.4        37.5                     2.9
# 7            26.2        29.1                    12.7
# ...           ...         ...                     ...
# 2389         11.7        51.0                    11.8
# 2390         11.0        39.9                    19.9
# 2391         15.9        42.3                    11.0
# 2392          8.9        57.5                     4.5
# 2393         12.3        50.3                     9.0
#
#       Never or not in the last 12 months
# 0                                   43.1
# 1                                   33.2
# 2                                   25.3
# 6                                   12.4
# 7                                    5.8
# ...                                  ...
# 2389                                12.0
# 2390                                19.9
# 2391                                18.1
# 2392                                 5.5
# 2393                                10.2
#
# [1176 rows x 9 columns]

# %% [markdown]
# ## Loading clusters

# %%
clu_folder=root+"data/clusters/"
clusters={}

number_of_clusters=[]

# Loading all clusters to memory
for dataset in datasets:
    cluster_number=0
    while True:
        cluster_path=clu_folder+dataset+"_clu_"+str(cluster_number)+".csv"
        if os.path.isfile(cluster_path):
            #print(cluster_path)
            clusters[(dataset,cluster_number)]=pd.read_csv(cluster_path,sep=";",index_col=0)
            cluster_number+=1
        else:
            number_of_clusters.append(cluster_number)
            break

clusters[("edu",3)]
# Out:
#                       age       geo      sex  \
# 13       75 years or over   Belgium  Females
# 110      75 years or over   Germany  Females
# 342   From 15 to 24 years   Austria  Females
# 343   From 15 to 24 years   Austria  Females
# 344   From 15 to 24 years   Austria  Females
# ...                   ...       ...      ...
# 2280  From 65 to 74 years    Norway    Males
# 2293  From 65 to 74 years    Poland    Males
# 2318  From 65 to 74 years   Romania    Males
# 2335  From 65 to 74 years  Slovakia    Males
# 2342  From 65 to 74 years  Slovenia  Females
#
#                                                 isced11  Every day  \
# 13                      Tertiary education (levels 5-8)       12.0
# 110   Upper secondary and post-secondary non-tertiar...        8.3
# 342   Less than primary, primary and lower secondary...        0.0
# 343                     Tertiary education (levels 5-8)        0.0
# 344   Upper secondary and post-secondary non-tertiar...        0.0
# ...                                                 ...        ...
# 2280  Less than primary, primary and lower secondary...        1.7
# 2293                    Tertiary education (levels 5-8)        4.1
# 2318  Upper secondary and post-secondary non-tertiar...       10.0
# 2335                    Tertiary education (levels 5-8)        2.6
# 2342  Upper secondary and post-secondary non-tertiar...        6.2
#
#       Every month  Every week  Less than once a month  \
# 13           29.8        27.9                     9.2
# 110          26.5        25.2                    13.8
# 342          41.4        17.6                    14.9
# 343          52.9        22.1                    15.7
# 344          43.0        23.1                    18.8
# ...           ...         ...                     ...
# 2280         43.2        42.0                     0.0
# 2293         34.0        19.4                    25.8
# 2318         31.8        22.7                     7.1
# 2335         24.1        26.2                    28.1
# 2342         25.4        22.9                    22.7
#
#       Never or not in the last 12 months  clusters
# 13                                  21.1         3
# 110                                 26.2         3
# 342                                 26.1         3
# 343                                  9.3         3
# 344                                 15.1         3
# ...                                  ...       ...
# 2280                                13.1         3
# 2293                                16.8         3
# 2318                                28.4         3
# 2335                                19.0         3
# 2342                                22.9         3
#
# [339 rows x 10 columns]

# %% [markdown]
# ## Verifying sex ratios

# %%
def get_sex_count(df):
    counts=df["sex"].value_counts()
    F=int(counts["Females"])
    M=int(counts["Males"])
    return F,M

# %%
for dataset,n in list(zip(datasets,number_of_clusters)):
    print(dataset)
    F,M=get_sex_count(cleans[dataset])
    print("Sex counts: ",F,M)
    Fs=[]
    Ms=[]
    for cluster_number in range(n):
        key=(dataset,cluster_number)
        print(key,end=":  ")
        f,m=get_sex_count(clusters[key])
        print(f,m)
        Fs.append(f)
        Ms.append(m)
    print(sum(Fs), sum(Ms))
    print()
# Out:
# edu
# Sex counts:  588 588
# ('edu', 0):  23 17
# ('edu', 1):  87 298
# ('edu', 2):  104 28
# ('edu', 3):  176 163
# ('edu', 4):  198 82
# 588 588
#
# inc
# Sex counts:  980 980
# ('inc', 0):  49 138
# ('inc', 1):  173 41
# ('inc', 2):  127 413
# ('inc', 3):  284 251
# ('inc', 4):  347 137
# 980 980
#
# urb
# Sex counts:  588 588
# ('urb', 0):  246 141
# ('urb', 1):  108 260
# ('urb', 2):  23 25
# ('urb', 3):  15 134
# ('urb', 4):  196 28
# 588 588

# %% [markdown]
# ## Verifying ages

# %%
labels=["From 15 to 24 years","From 25 to 34 years","From 35 to 44 years","From 45 to 54 years", "From 55 to 64 years","From 65 to 74 years","75 years or over"]

def get_age_count(df):
    counts=df["age"].value_counts()
    ages=[]
    for i in range(len(labels)):
        ages.append(int(counts.get(labels[i],0)))
    return ages


for dataset,n in list(zip(datasets,number_of_clusters)):
    print(dataset)
    ages_total=get_age_count(cleans[dataset])
    print("Age counts: ",ages_total)
    
    ages=[]
    for cluster_number in range(n):
        key=(dataset,cluster_number)
        print(key,end=":  ")
        counts=get_age_count(clusters[key])
        print(counts)
        ages.append(counts)
    
    sums=[]
    for age_group in range(len(ages_total)):
        aux=0
        for i in range(n):
            aux+=ages[i][age_group]
        sums.append(aux)
    print("Sums are: ", sums)
    print()
# Out:
# edu
# Age counts:  [168, 168, 168, 168, 168, 168, 168]
# ('edu', 0):  [13, 8, 2, 5, 0, 2, 10]
# ('edu', 1):  [22, 39, 57, 66, 82, 74, 45]
# ('edu', 2):  [25, 12, 11, 11, 16, 21, 36]
# ('edu', 3):  [76, 82, 59, 57, 36, 27, 2]
# ('edu', 4):  [32, 27, 39, 29, 34, 44, 75]
# Sums are:  [168, 168, 168, 168, 168, 168, 168]
#
# inc
# Age counts:  [280, 280, 280, 280, 280, 280, 280]
# ('inc', 0):  [11, 1, 6, 7, 30, 45, 87]
# ('inc', 1):  [29, 15, 15, 16, 24, 41, 74]
# ('inc', 2):  [37, 72, 93, 115, 107, 84, 32]
# ('inc', 3):  [104, 140, 112, 83, 53, 39, 4]
# ('inc', 4):  [99, 52, 54, 59, 66, 71, 83]
# Sums are:  [280, 280, 280, 280, 280, 280, 280]
#
# urb
# Age counts:  [168, 168, 168, 168, 168, 168, 168]
# ('urb', 0):  [96, 80, 63, 49, 37, 36, 26]
# ('urb', 1):  [31, 69, 77, 84, 66, 35, 6]
# ('urb', 2):  [7, 6, 7, 6, 6, 6, 10]
# ('urb', 3):  [0, 0, 8, 15, 32, 50, 44]
# ('urb', 4):  [34, 13, 13, 14, 27, 41, 82]
# Sums are:  [168, 168, 168, 168, 168, 168, 168]
